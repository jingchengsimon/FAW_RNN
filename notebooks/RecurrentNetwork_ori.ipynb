# %%
import numpy as np
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
# list cuda devices
print("Available CUDA devices:")
for i in range(torch.cuda.device_count()):
    print(f"Device {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Available CUDA devices:
# Device 0: NVIDIA RTX A6000
# Device 1: NVIDIA RTX A6000

# %% [markdown]
# ## Recurrent network simulation

# %%
# Create dataset class for loading stacks of frames as multichannel images
# for use in testing the performance of RNN models
class MC_RNN_Dataset(Dataset):
    def __init__(self, data, labels, frame_num=32, chan_num=2):
        """
        Args:
            data (np.ndarray): Array of shape (num_samples, num_frames, height, width)
            labels (np.ndarray): Array of shape (num_samples,) with labels
            frame_num (int): Number of frames to stack for input as multichannel image
            chan_num (int): Number of channels in the input images. Each channel is a 
            previous frame.
        """

        self.data = data
        self.labels = labels[['fg_char_id', 'fg_char_x', 'fg_char_y']].values
        self.frame_num = frame_num
        self.chan_num = chan_num

    def __len__(self):
        return (self.data.shape[0]-self.chan_num) // self.frame_num

    def __getitem__(self, idx):
        start_idx = (idx * self.frame_num) + self.chan_num
        end_idx = start_idx + self.frame_num

        # Stack frames to create a multichannel image
        for i in range(-(self.chan_num-1), 1):
            if i == -(self.chan_num-1):
                stacked_frames = np.expand_dims(self.data[(start_idx + i):(end_idx + i)], axis=1)
            else:
                stacked_frames = np.concatenate((stacked_frames, 
                                                 np.expand_dims(self.data[(start_idx + i):(end_idx + i)], 
                                                                axis=1)), axis=1)
        stacked_frames = stacked_frames.astype(np.float32)

        # insert channel dimension
        labels = self.labels[start_idx:end_idx]
        return stacked_frames, labels

# %%
# train feedforward network
def network_train(mdl, train_data, val_data, num_epochs=50, loss_weights=[1, 0.01], lr=0.001):
    mdl.to('cuda')
    optim = torch.optim.Adam(mdl.parameters(), lr=lr)
    criterion_char = nn.CrossEntropyLoss()
    criterion_pos = nn.MSELoss()
    
    # Define loss functions
    def loss_fn(out_char, out_pos, labels):
        labels_char = labels[:, :, 0].long().view(-1)
        labels_pos = labels[:, :, 1:].float().view(-1, 2)
        outputs_char = out_char.view(-1, out_char.shape[-1])
        outputs_pos = out_pos.view(-1, out_pos.shape[-1])
        loss_char = criterion_char(outputs_char, labels_char)
        loss_pos = criterion_pos(outputs_pos, labels_pos)
        rnn_hh = mdl.rnn.weight_hh_l0
        # sum elements along diagonal of rnn_hh
        rnn_hh_diag = torch.diagonal(rnn_hh).abs().sum()
        loss = (loss_weights[0] * loss_char) + (loss_weights[1] * loss_pos) + rnn_hh_diag
        return loss

    def evaluate(mdl, data_loader):
        mdl.eval()
        total_acc_char = 0
        total_err_pos = 0
        with torch.no_grad():
            for batch in data_loader:
                inputs, labels = batch
                labels = labels.to(mdl.device)
                out_char, out_pos = mdl(inputs)
                total_acc_char += (torch.argmax(out_char, dim=2) == labels[:, :, 0].long()).float().mean().item()
                total_err_pos += F.mse_loss(out_pos, labels[:, :, 1:].float(), reduction='mean').item()
        return total_acc_char*100 / len(data_loader), total_err_pos / len(data_loader)

    # data loader
    train_dl = DataLoader(train_data, batch_size=32, shuffle=True)
    val_dl = DataLoader(val_data, batch_size=32, shuffle=True)
    train_acc_char = np.zeros(num_epochs)
    val_acc_char = np.zeros(num_epochs)
    train_err_pos = np.zeros(num_epochs)
    val_err_pos = np.zeros(num_epochs)
    for epoch in range(num_epochs):
        mdl.train()
        for batch in train_dl:
            inputs, labels = batch
            labels = labels.to(mdl.device)            
            optim.zero_grad()
            out_char, out_pos = mdl(inputs)
            loss = loss_fn(out_char, out_pos, labels)
            loss.backward()
            optim.step()
            train_acc_char[epoch] += (torch.argmax(out_char, dim=2) == labels[:, :, 0].long()).float().mean().item()
            train_err_pos[epoch] += F.mse_loss(out_pos, labels[:, :, 1:].float(), reduction='mean').item()

        train_acc_char[epoch] /= len(train_dl)
        train_acc_char[epoch] *= 100  # Convert to percentage
        train_err_pos[epoch] /= len(train_dl)
        train_str = f"Epoch {epoch + 1}/{num_epochs} - Train (char, pos): ({train_acc_char[epoch]:.2f}%, {train_err_pos[epoch]:.2f} pix^2)"

        # Print accuracy on character id for validation data
        with torch.no_grad():
            val_acc_char[epoch], val_err_pos[epoch] = evaluate(mdl, val_dl)
            val_str = f" Validation (char, pos): ({val_acc_char[epoch]:.2f}%, {val_err_pos[epoch]:.2f} pix^2)"
            print(train_str, val_str)

    torch.cuda.empty_cache()

    return {
        "train_acc_char": train_acc_char,
        "val_acc_char": val_acc_char,
        "train_err_pos": train_err_pos,
        "val_err_pos": val_err_pos,
        "model": mdl.to("cpu")
    }

# %%
# calculate module parameter count
def model_param_count(mdl):
    return sum(p.numel() for p in mdl.parameters() if p.requires_grad)

# %%
# Create dataset class for loading stacks of frames as multichannel images
# for use in testing the performance of recurrent models
class RNNConv(nn.Module):
    def __init__(self, num_classes, num_pos, kernel_size=3, device='cuda'):
        super(RNNConv, self).__init__()
        self.device = device
        self.conv1 = nn.Conv2d(2, 32, kernel_size=kernel_size, padding='same')
        self.MP1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.LNorm1 = nn.LayerNorm([32, 48, 48])
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.MP2 = nn.MaxPool2d(kernel_size=4, stride=4)
        self.LNorm2 = nn.LayerNorm([64, 12, 12])
        self.rnn = nn.RNN(input_size=64 * 12 * 12, hidden_size=256, 
                          num_layers=1, batch_first=True)
        self.LNormRNN = nn.LayerNorm(256)
        self.fcchar = nn.Linear(256, num_classes)
        self.fcpos = nn.Linear(256, num_pos)
        self.to(self.device)

    def encoder(self, x):
        return nn.Sequential(
            self.conv1,
            self.MP1,
            self.LNorm1,
            nn.ReLU(),
            self.conv2,
            self.MP2,
            self.LNorm2,
            nn.ReLU()
        )(x)

    def middle(self, x):
        x = self.rnn(x)[0]
        x = self.LNormRNN(x)
        x = nn.Dropout(0.5)(nn.ReLU()(x))
        return x

    def classifier(self, x):
        return self.fcchar(x), self.fcpos(x)

    def forward(self, x):
        x = x.to(self.device)

        batch_size, frame_num, channels, height, width = x.size()

        # resize to process each frame individually
        x = x.view(batch_size * frame_num, channels, height, width)

        # apply CNN encoder
        x = self.encoder(x)
        
        # reshape back to batches of stacks of frames and flatten each image
        x = x.view(batch_size, frame_num, -1)

        # apply RNN
        x = self.middle(x)

        # apply classification heads
        char_out, pos_out = self.classifier(x)
        return char_out, pos_out

# %%
# 封装的可视化函数和保存/加载功能
def visualize_results(results, model, test_ds, test_dl, use_sector=False, num_sectors=10, num_vis=8):
    """
    可视化训练结果和测试集预测
    
    Args:
        results: 训练结果字典，包含 'train_acc_char', 'val_acc_char' 等（不包含 'model'）
        model: 训练好的模型对象（单独传递）
        test_ds: 测试数据集
        test_dl: 测试数据加载器
        use_sector: 如果为 True，则可视化 sector location；否则可视化坐标
        num_sectors: sector 数量（仅在 use_sector=True 时使用）
        num_vis: 可视化的样本数量
    """
    # 1. 绘制训练 / 验证性能曲线
    plt.figure(figsize=(12, 5))
    
    # 字符识别准确率
    plt.subplot(1, 2, 1)
    plt.plot(results["train_acc_char"], label="train char acc")
    plt.plot(results["val_acc_char"], label="val char acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.title("Character accuracy")
    plt.legend()
    
    # 位置相关指标
    plt.subplot(1, 2, 2)
    if use_sector:
        # sector 模式：显示准确率
        if "train_acc_pos" in results and "val_acc_pos" in results:
            plt.plot(results["train_acc_pos"], label="train sector acc")
            plt.plot(results["val_acc_pos"], label="val sector acc")
            plt.ylabel("Accuracy (%)")
            plt.title("Sector accuracy")
        else:
            print("Warning: train_acc_pos or val_acc_pos not found in results")
    else:
        # 坐标模式：显示 MSE
        if "train_err_pos" in results and "val_err_pos" in results:
            plt.plot(results["train_err_pos"], label="train pos MSE")
            plt.plot(results["val_err_pos"], label="val pos MSE")
            plt.ylabel("MSE (pixel^2)")
            plt.title("Position error")
        else:
            print("Warning: train_err_pos or val_err_pos not found in results")
    plt.xlabel("Epoch")
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # 2. 使用训练好的模型在 test set 上推理
    mdl_eval = model
    # 检测设备：如果 CUDA 可用，使用 CUDA；否则使用 CPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    mdl_eval = mdl_eval.to(device)
    mdl_eval.device = device.type  # 设置模型内部的 device 属性
    mdl_eval.eval()
    
    all_char_pred = []
    all_char_gt = []
    all_pos_pred = []
    all_pos_gt = []
    
    with torch.no_grad():
        for batch in test_dl:
            inputs, labels = batch
            # 确保输入数据在正确的设备上
            inputs = inputs.to(device)
            labels = labels.to(device)
            out_char, out_pos = mdl_eval(inputs)
            
            # 取每个序列最后一帧的预测
            pred_char = torch.argmax(out_char[:, -1, :], dim=-1).cpu().numpy()
            gt_char = labels[:, -1, 0].long().cpu().numpy()
            
            if use_sector:
                # sector 模式：预测和 GT 都是 sector id
                pred_pos = torch.argmax(out_pos[:, -1, :], dim=-1).cpu().numpy()
                gt_pos = labels[:, -1, 1].long().cpu().numpy()
            else:
                # 坐标模式：预测和 GT 都是 (x, y) 坐标
                pred_pos = out_pos[:, -1, :].cpu().numpy()
                gt_pos = labels[:, -1, 1:].float().cpu().numpy()
            
            all_char_pred.append(pred_char)
            all_char_gt.append(gt_char)
            all_pos_pred.append(pred_pos)
            all_pos_gt.append(gt_pos)
    
    # 拼接为 numpy 数组
    all_char_pred = np.concatenate(all_char_pred, axis=0)
    all_char_gt = np.concatenate(all_char_gt, axis=0)
    all_pos_pred = np.concatenate(all_pos_pred, axis=0)
    all_pos_gt = np.concatenate(all_pos_gt, axis=0)
    
    # 计算 test 上整体性能
    char_acc_test = (all_char_pred == all_char_gt).mean() * 100.0
    if use_sector:
        pos_acc_test = (all_pos_pred == all_pos_gt).mean() * 100.0
        print(f"Test character accuracy: {char_acc_test:.2f}%")
        print(f"Test sector accuracy: {pos_acc_test:.2f}%")
    else:
        pos_mse_test = ((all_pos_pred - all_pos_gt) ** 2).mean()
        print(f"Test character accuracy: {char_acc_test:.2f}%")
        print(f"Test position MSE: {pos_mse_test:.2f} pixel^2")
    
    # 3. 可视化若干 test 样本
    fig, axes = plt.subplots(2, num_vis // 2, figsize=(3 * (num_vis // 2), 6))
    axes = axes.flatten()
    
    # 获取图像宽度（用于 sector 可视化）
    img_width = test_ds.data.shape[-1] if hasattr(test_ds, 'data') else 96
    img_height = test_ds.data.shape[-2] if hasattr(test_ds, 'data') else 96

    # 根据 num_sectors 计算 grid_size（例如 num_sectors=9 -> grid_size=3）
    if use_sector:
        grid_size = int(np.sqrt(num_sectors))
        if grid_size * grid_size != num_sectors:
            raise ValueError(f"num_sectors={num_sectors} 不是完全平方数，无法构成 grid_size x grid_size 网格")
    
    for i in range(num_vis):
        img_seq, label_seq = test_ds[i]
        last_frame = img_seq[-1, 0]
        
        ax = axes[i]
        ax.imshow(last_frame, cmap="gray")
        
        # 添加 3x3 白色网格线，便于判断 sector location
        # 绘制2条垂直线（将图像分成3列）
        for j in range(1, 3):
            x_pos = j * img_width / 3
            ax.axvline(x=x_pos, color='white', linewidth=1.5, alpha=0.8)
        # 绘制2条水平线（将图像分成3行）
        for j in range(1, 3):
            y_pos = j * img_height / 3
            ax.axhline(y=y_pos, color='white', linewidth=1.5, alpha=0.8)
        
        # GT
        gt_c = int(all_char_gt[i])
        if use_sector:
            # sector 模式：显示 sector id
            gt_sector = int(all_pos_gt[i])

            # 将 sector id 解码为 (row, col)
            gt_row = gt_sector // grid_size
            gt_col = gt_sector % grid_size

            # 计算 sector 中心坐标（放在对应 0-(num_sectors-1) sector 的正中间）
            gt_x = (gt_col + 0.5) * (img_width / grid_size)
            gt_y = (gt_row + 0.5) * (img_height / grid_size)

            ax.scatter([gt_x], [gt_y], c="lime", s=40, label="GT" if i == 0 else "")
            ax.text(gt_x + 1, gt_y + 1, f"C{gt_c}/S{gt_sector}", color="lime", fontsize=8)
            
            # Pred
            pd_c = int(all_char_pred[i])
            pd_sector = int(all_pos_pred[i])
            pd_row = pd_sector // grid_size
            pd_col = pd_sector % grid_size

            pd_x = (pd_col + 0.5) * (img_width / grid_size)
            pd_y = (pd_row + 0.5) * (img_height / grid_size)

            ax.scatter([pd_x], [pd_y], c="red", s=40, marker="x", label="Pred" if i == 0 else "")
            ax.text(pd_x + 1, pd_y + 1, f"C{pd_c}/S{pd_sector}", color="red", fontsize=8)
        else:
            # 坐标模式：显示 (x, y) 坐标
            gt_x, gt_y = all_pos_gt[i]
            ax.scatter([gt_x], [gt_y], c="lime", s=40, label="GT" if i == 0 else "")
            ax.text(gt_x + 1, gt_y + 1, str(gt_c), color="lime", fontsize=10)
            
            # Pred
            pd_c = int(all_char_pred[i])
            pd_x, pd_y = all_pos_pred[i]
            ax.scatter([pd_x], [pd_y], c="red", s=40, marker="x", label="Pred" if i == 0 else "")
            ax.text(pd_x + 1, pd_y + 1, str(pd_c), color="red", fontsize=10)
        
        ax.set_axis_off()
    
    # 统一 legend
    handles, labels_legend = axes[0].get_legend_handles_labels()
    if handles:
        fig.legend(handles, labels_legend, loc="upper right")
    
    plt.tight_layout()
    plt.show()

# %%
stim_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.npy"
label_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.tsv"
stims_train = np.load(stim_train_path, allow_pickle=True)
lbls_train = pd.read_csv(label_train_path, sep="\t", index_col=0)

stim_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.npy"
label_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.tsv"
stims_val = np.load(stim_val_path, allow_pickle=True)
lbls_val = pd.read_csv(label_val_path, sep="\t", index_col=0)


train_ds = MC_RNN_Dataset(stims_train, lbls_train)
val_ds = MC_RNN_Dataset(stims_val, lbls_val)
mdl_rnn = RNNConv(num_classes=10, num_pos=2, kernel_size=5)
print(f"RNN model parameter count: {model_param_count(mdl_rnn)}")
results_rnn = network_train(mdl_rnn, train_ds, val_ds, num_epochs=200, loss_weights=[1.0, 0.001])
# Out:
# RNN model parameter count: 2614956
# Epoch 1/200 - Train (char, pos): (10.26%, 1046.66 pix^2)  Validation (char, pos): (10.28%, 415.74 pix^2)
# Epoch 2/200 - Train (char, pos): (11.52%, 355.66 pix^2)  Validation (char, pos): (14.44%, 329.71 pix^2)
# Epoch 3/200 - Train (char, pos): (17.93%, 290.97 pix^2)  Validation (char, pos): (18.73%, 270.34 pix^2)
# Epoch 4/200 - Train (char, pos): (23.93%, 253.66 pix^2)  Validation (char, pos): (26.15%, 239.18 pix^2)
# Epoch 5/200 - Train (char, pos): (32.47%, 224.89 pix^2)  Validation (char, pos): (32.41%, 209.38 pix^2)
# Epoch 6/200 - Train (char, pos): (42.43%, 197.76 pix^2)  Validation (char, pos): (39.56%, 202.90 pix^2)
# Epoch 7/200 - Train (char, pos): (51.02%, 181.38 pix^2)  Validation (char, pos): (46.76%, 182.93 pix^2)
# Epoch 8/200 - Train (char, pos): (59.38%, 166.67 pix^2)  Validation (char, pos): (48.98%, 181.29 pix^2)
# Epoch 9/200 - Train (char, pos): (65.62%, 157.96 pix^2)  Validation (char, pos): (49.93%, 168.91 pix^2)
# Epoch 10/200 - Train (char, pos): (71.13%, 152.14 pix^2)  Validation (char, pos): (53.15%, 160.84 pix^2)
# Epoch 11/200 - Train (char, pos): (76.78%, 144.26 pix^2)  Validation (char, pos): (53.86%, 166.47 pix^2)
# Epoch 12/200 - Train (char, pos): (79.82%, 141.56 pix^2)  Validation (char, pos): (54.43%, 168.00 pix^2)
# Epoch 13/200 - Train (char, pos): (83.27%, 135.33 pix^2)  Validation (char, pos): (54.87%, 163.11 pix^2)
# Epoch 14/200 - Train (char, pos): (85.83%, 132.21 pix^2)  Validation (char, pos): (50.91%, 166.86 pix^2)
# Epoch 15/200 - Train (char, pos): (87.58%, 129.41 pix^2)  Validation (char, pos): (55.04%, 173.81 pix^2)
# Epoch 16/200 - Train (char, pos): (83.15%, 135.09 pix^2)  Validation (char, pos): (54.83%, 167.43 pix^2)
# Epoch 17/200 - Train (char, pos): (90.04%, 124.73 pix^2)  Validation (char, pos): (54.18%, 164.03 pix^2)
# Epoch 18/200 - Train (char, pos): (91.35%, 123.36 pix^2)  Validation (char, pos): (56.61%, 157.29 pix^2)
# Epoch 19/200 - Train (char, pos): (93.75%, 116.70 pix^2)  Validation (char, pos): (57.07%, 155.88 pix^2)
# Epoch 20/200 - Train (char, pos): (95.04%, 112.58 pix^2)  Validation (char, pos): (56.86%, 158.11 pix^2)
# Epoch 21/200 - Train (char, pos): (88.42%, 124.34 pix^2)  Validation (char, pos): (53.83%, 173.67 pix^2)
# Epoch 22/200 - Train (char, pos): (91.40%, 122.18 pix^2)  Validation (char, pos): (56.24%, 158.74 pix^2)
# Epoch 23/200 - Train (char, pos): (95.24%, 112.21 pix^2)  Validation (char, pos): (57.56%, 158.54 pix^2)
# Epoch 24/200 - Train (char, pos): (96.23%, 108.32 pix^2)  Validation (char, pos): (55.93%, 159.40 pix^2)
# Epoch 25/200 - Train (char, pos): (96.77%, 105.09 pix^2)  Validation (char, pos): (57.41%, 156.02 pix^2)
# Epoch 26/200 - Train (char, pos): (97.18%, 101.72 pix^2)  Validation (char, pos): (57.50%, 162.17 pix^2)
# Epoch 27/200 - Train (char, pos): (97.49%, 99.27 pix^2)  Validation (char, pos): (57.03%, 155.92 pix^2)
# Epoch 28/200 - Train (char, pos): (84.70%, 124.31 pix^2)  Validation (char, pos): (53.65%, 166.44 pix^2)
# Epoch 29/200 - Train (char, pos): (87.17%, 126.10 pix^2)  Validation (char, pos): (53.58%, 166.00 pix^2)
# Epoch 30/200 - Train (char, pos): (94.18%, 111.65 pix^2)  Validation (char, pos): (55.89%, 163.33 pix^2)
# Epoch 31/200 - Train (char, pos): (95.96%, 105.76 pix^2)  Validation (char, pos): (57.68%, 156.32 pix^2)
# Epoch 32/200 - Train (char, pos): (96.84%, 102.57 pix^2)  Validation (char, pos): (57.03%, 161.16 pix^2)
# Epoch 33/200 - Train (char, pos): (97.52%, 98.69 pix^2)  Validation (char, pos): (57.53%, 157.59 pix^2)
# Epoch 34/200 - Train (char, pos): (97.93%, 95.98 pix^2)  Validation (char, pos): (57.16%, 156.13 pix^2)
# Epoch 35/200 - Train (char, pos): (98.00%, 93.54 pix^2)  Validation (char, pos): (57.00%, 156.12 pix^2)
# Epoch 36/200 - Train (char, pos): (98.21%, 91.88 pix^2)  Validation (char, pos): (57.32%, 154.21 pix^2)
# Epoch 37/200 - Train (char, pos): (86.85%, 120.45 pix^2)  Validation (char, pos): (53.65%, 159.86 pix^2)
# Epoch 38/200 - Train (char, pos): (90.61%, 114.57 pix^2)  Validation (char, pos): (55.08%, 161.59 pix^2)
# Epoch 39/200 - Train (char, pos): (95.85%, 103.65 pix^2)  Validation (char, pos): (55.60%, 158.40 pix^2)
# Epoch 40/200 - Train (char, pos): (97.47%, 96.85 pix^2)  Validation (char, pos): (56.71%, 156.66 pix^2)
# Epoch 41/200 - Train (char, pos): (97.99%, 93.88 pix^2)  Validation (char, pos): (56.26%, 155.06 pix^2)
# Epoch 42/200 - Train (char, pos): (98.21%, 91.61 pix^2)  Validation (char, pos): (57.09%, 156.78 pix^2)
# Epoch 43/200 - Train (char, pos): (98.38%, 89.38 pix^2)  Validation (char, pos): (57.16%, 155.92 pix^2)
# Epoch 44/200 - Train (char, pos): (98.55%, 87.60 pix^2)  Validation (char, pos): (57.76%, 157.13 pix^2)
# Epoch 45/200 - Train (char, pos): (98.65%, 85.86 pix^2)  Validation (char, pos): (57.04%, 152.37 pix^2)
# Epoch 46/200 - Train (char, pos): (98.72%, 84.29 pix^2)  Validation (char, pos): (56.75%, 157.32 pix^2)
# Epoch 47/200 - Train (char, pos): (91.22%, 102.14 pix^2)  Validation (char, pos): (50.46%, 172.63 pix^2)
# Epoch 48/200 - Train (char, pos): (85.21%, 121.05 pix^2)  Validation (char, pos): (54.45%, 163.38 pix^2)
# Epoch 49/200 - Train (char, pos): (90.27%, 118.40 pix^2)  Validation (char, pos): (56.31%, 155.62 pix^2)
# Epoch 50/200 - Train (char, pos): (96.74%, 98.32 pix^2)  Validation (char, pos): (57.28%, 156.62 pix^2)
# Epoch 51/200 - Train (char, pos): (97.78%, 92.78 pix^2)  Validation (char, pos): (57.54%, 154.09 pix^2)
# Epoch 52/200 - Train (char, pos): (98.26%, 89.91 pix^2)  Validation (char, pos): (57.70%, 156.58 pix^2)
# Epoch 53/200 - Train (char, pos): (98.48%, 87.51 pix^2)  Validation (char, pos): (57.25%, 155.33 pix^2)
# Epoch 54/200 - Train (char, pos): (98.66%, 85.02 pix^2)  Validation (char, pos): (57.65%, 157.50 pix^2)
# Epoch 55/200 - Train (char, pos): (98.76%, 83.32 pix^2)  Validation (char, pos): (57.68%, 152.95 pix^2)
# Epoch 56/200 - Train (char, pos): (98.87%, 81.47 pix^2)  Validation (char, pos): (57.68%, 154.77 pix^2)
# Epoch 57/200 - Train (char, pos): (98.92%, 80.16 pix^2)  Validation (char, pos): (57.56%, 155.63 pix^2)
# Epoch 58/200 - Train (char, pos): (98.83%, 79.25 pix^2)  Validation (char, pos): (52.48%, 163.40 pix^2)
# Epoch 59/200 - Train (char, pos): (88.82%, 111.34 pix^2)  Validation (char, pos): (53.89%, 158.43 pix^2)
# Epoch 60/200 - Train (char, pos): (94.66%, 99.87 pix^2)  Validation (char, pos): (55.41%, 158.43 pix^2)
# Epoch 61/200 - Train (char, pos): (95.98%, 97.51 pix^2)  Validation (char, pos): (53.92%, 156.60 pix^2)
# Epoch 62/200 - Train (char, pos): (97.55%, 89.50 pix^2)  Validation (char, pos): (56.10%, 155.43 pix^2)
# Epoch 63/200 - Train (char, pos): (98.43%, 84.82 pix^2)  Validation (char, pos): (56.87%, 152.61 pix^2)
# Epoch 64/200 - Train (char, pos): (98.67%, 82.36 pix^2)  Validation (char, pos): (55.56%, 156.26 pix^2)
# Epoch 65/200 - Train (char, pos): (98.84%, 80.73 pix^2)  Validation (char, pos): (57.48%, 153.65 pix^2)
# Epoch 66/200 - Train (char, pos): (98.96%, 78.62 pix^2)  Validation (char, pos): (57.08%, 153.80 pix^2)
# Epoch 67/200 - Train (char, pos): (99.07%, 77.11 pix^2)  Validation (char, pos): (57.12%, 152.85 pix^2)
# Epoch 68/200 - Train (char, pos): (99.14%, 75.72 pix^2)  Validation (char, pos): (56.84%, 154.63 pix^2)
# Epoch 69/200 - Train (char, pos): (99.15%, 74.73 pix^2)  Validation (char, pos): (56.54%, 156.36 pix^2)
# Epoch 70/200 - Train (char, pos): (90.84%, 98.33 pix^2)  Validation (char, pos): (50.19%, 172.21 pix^2)
# Epoch 71/200 - Train (char, pos): (92.26%, 103.73 pix^2)  Validation (char, pos): (55.04%, 160.50 pix^2)
# Epoch 72/200 - Train (char, pos): (95.93%, 91.30 pix^2)  Validation (char, pos): (55.12%, 153.24 pix^2)
# Epoch 73/200 - Train (char, pos): (97.57%, 85.80 pix^2)  Validation (char, pos): (57.11%, 151.08 pix^2)
# Epoch 74/200 - Train (char, pos): (98.50%, 81.24 pix^2)  Validation (char, pos): (57.26%, 151.53 pix^2)
# Epoch 75/200 - Train (char, pos): (98.79%, 79.05 pix^2)  Validation (char, pos): (57.46%, 151.87 pix^2)
# Epoch 76/200 - Train (char, pos): (98.94%, 77.44 pix^2)  Validation (char, pos): (57.60%, 151.77 pix^2)
# Epoch 77/200 - Train (char, pos): (99.04%, 75.46 pix^2)  Validation (char, pos): (57.58%, 151.82 pix^2)
# Epoch 78/200 - Train (char, pos): (99.16%, 74.05 pix^2)  Validation (char, pos): (58.08%, 152.83 pix^2)
# Epoch 79/200 - Train (char, pos): (99.18%, 72.62 pix^2)  Validation (char, pos): (57.80%, 152.75 pix^2)
# Epoch 80/200 - Train (char, pos): (99.21%, 71.84 pix^2)  Validation (char, pos): (57.69%, 151.38 pix^2)
# Epoch 81/200 - Train (char, pos): (94.27%, 83.49 pix^2)  Validation (char, pos): (45.87%, 177.89 pix^2)
# Epoch 82/200 - Train (char, pos): (90.98%, 103.89 pix^2)  Validation (char, pos): (55.00%, 163.64 pix^2)
# Epoch 83/200 - Train (char, pos): (97.72%, 83.82 pix^2)  Validation (char, pos): (55.39%, 156.09 pix^2)
# Epoch 84/200 - Train (char, pos): (98.47%, 79.33 pix^2)  Validation (char, pos): (55.52%, 154.99 pix^2)
# Epoch 85/200 - Train (char, pos): (98.82%, 76.60 pix^2)  Validation (char, pos): (56.06%, 156.60 pix^2)
# Epoch 86/200 - Train (char, pos): (99.00%, 74.68 pix^2)  Validation (char, pos): (55.60%, 156.46 pix^2)
# Epoch 87/200 - Train (char, pos): (99.13%, 72.93 pix^2)  Validation (char, pos): (56.49%, 152.72 pix^2)
# Epoch 88/200 - Train (char, pos): (99.19%, 71.56 pix^2)  Validation (char, pos): (56.28%, 155.19 pix^2)
# Epoch 89/200 - Train (char, pos): (99.23%, 70.59 pix^2)  Validation (char, pos): (56.60%, 154.64 pix^2)
# Epoch 90/200 - Train (char, pos): (99.29%, 69.25 pix^2)  Validation (char, pos): (56.68%, 153.04 pix^2)
# Epoch 91/200 - Train (char, pos): (99.34%, 68.09 pix^2)  Validation (char, pos): (56.81%, 154.65 pix^2)
# Epoch 92/200 - Train (char, pos): (99.35%, 67.35 pix^2)  Validation (char, pos): (56.30%, 154.11 pix^2)
# Epoch 93/200 - Train (char, pos): (99.34%, 66.46 pix^2)  Validation (char, pos): (56.65%, 156.86 pix^2)
# Epoch 94/200 - Train (char, pos): (88.83%, 91.10 pix^2)  Validation (char, pos): (47.68%, 177.77 pix^2)
# Epoch 95/200 - Train (char, pos): (90.85%, 98.35 pix^2)  Validation (char, pos): (53.61%, 159.05 pix^2)
# Epoch 96/200 - Train (char, pos): (96.90%, 83.68 pix^2)  Validation (char, pos): (55.73%, 153.80 pix^2)
# Epoch 97/200 - Train (char, pos): (98.27%, 77.45 pix^2)  Validation (char, pos): (56.61%, 155.93 pix^2)
# Epoch 98/200 - Train (char, pos): (98.74%, 74.58 pix^2)  Validation (char, pos): (56.54%, 152.79 pix^2)
# Epoch 99/200 - Train (char, pos): (98.95%, 72.12 pix^2)  Validation (char, pos): (56.81%, 154.59 pix^2)
# Epoch 100/200 - Train (char, pos): (99.10%, 70.33 pix^2)  Validation (char, pos): (56.90%, 154.22 pix^2)
# Epoch 101/200 - Train (char, pos): (99.21%, 68.92 pix^2)  Validation (char, pos): (56.96%, 155.54 pix^2)
# Epoch 102/200 - Train (char, pos): (99.28%, 67.50 pix^2)  Validation (char, pos): (57.12%, 154.06 pix^2)
# Epoch 103/200 - Train (char, pos): (99.33%, 66.32 pix^2)  Validation (char, pos): (57.15%, 154.35 pix^2)
# Epoch 104/200 - Train (char, pos): (99.38%, 65.37 pix^2)  Validation (char, pos): (56.83%, 156.33 pix^2)
# Epoch 105/200 - Train (char, pos): (99.43%, 64.18 pix^2)  Validation (char, pos): (56.65%, 157.14 pix^2)
# Epoch 106/200 - Train (char, pos): (99.42%, 63.39 pix^2)  Validation (char, pos): (56.90%, 153.78 pix^2)
# Epoch 107/200 - Train (char, pos): (90.83%, 91.75 pix^2)  Validation (char, pos): (51.40%, 161.45 pix^2)
# Epoch 108/200 - Train (char, pos): (91.54%, 93.65 pix^2)  Validation (char, pos): (55.36%, 158.73 pix^2)
# Epoch 109/200 - Train (char, pos): (97.58%, 77.33 pix^2)  Validation (char, pos): (55.30%, 154.96 pix^2)
# Epoch 110/200 - Train (char, pos): (98.35%, 73.44 pix^2)  Validation (char, pos): (56.33%, 153.21 pix^2)
# Epoch 111/200 - Train (char, pos): (98.88%, 70.56 pix^2)  Validation (char, pos): (56.07%, 156.05 pix^2)
# Epoch 112/200 - Train (char, pos): (99.08%, 68.28 pix^2)  Validation (char, pos): (56.23%, 153.41 pix^2)
# Epoch 113/200 - Train (char, pos): (99.18%, 67.06 pix^2)  Validation (char, pos): (56.75%, 154.49 pix^2)
# Epoch 114/200 - Train (char, pos): (99.27%, 65.60 pix^2)  Validation (char, pos): (56.76%, 153.96 pix^2)
# Epoch 115/200 - Train (char, pos): (99.34%, 64.17 pix^2)  Validation (char, pos): (56.42%, 156.61 pix^2)
# Epoch 116/200 - Train (char, pos): (99.39%, 63.32 pix^2)  Validation (char, pos): (56.77%, 153.26 pix^2)
# Epoch 117/200 - Train (char, pos): (99.42%, 62.23 pix^2)  Validation (char, pos): (56.71%, 156.24 pix^2)
# Epoch 118/200 - Train (char, pos): (99.45%, 61.49 pix^2)  Validation (char, pos): (56.82%, 154.61 pix^2)
# Epoch 119/200 - Train (char, pos): (93.23%, 83.32 pix^2)  Validation (char, pos): (53.78%, 149.88 pix^2)
# Epoch 120/200 - Train (char, pos): (94.65%, 87.29 pix^2)  Validation (char, pos): (47.95%, 200.40 pix^2)
# Epoch 121/200 - Train (char, pos): (96.28%, 83.91 pix^2)  Validation (char, pos): (54.65%, 158.49 pix^2)
# Epoch 122/200 - Train (char, pos): (98.55%, 72.88 pix^2)  Validation (char, pos): (55.58%, 149.62 pix^2)
# Epoch 123/200 - Train (char, pos): (98.96%, 69.25 pix^2)  Validation (char, pos): (55.69%, 151.81 pix^2)
# Epoch 124/200 - Train (char, pos): (99.13%, 67.12 pix^2)  Validation (char, pos): (55.98%, 150.84 pix^2)
# Epoch 125/200 - Train (char, pos): (99.27%, 65.56 pix^2)  Validation (char, pos): (55.83%, 154.26 pix^2)
# Epoch 126/200 - Train (char, pos): (99.35%, 64.43 pix^2)  Validation (char, pos): (55.91%, 153.79 pix^2)
# Epoch 127/200 - Train (char, pos): (99.37%, 63.18 pix^2)  Validation (char, pos): (56.15%, 150.79 pix^2)
# Epoch 128/200 - Train (char, pos): (99.41%, 62.25 pix^2)  Validation (char, pos): (56.17%, 154.30 pix^2)
# Epoch 129/200 - Train (char, pos): (99.47%, 61.00 pix^2)  Validation (char, pos): (56.23%, 156.98 pix^2)
# Epoch 130/200 - Train (char, pos): (99.47%, 60.17 pix^2)  Validation (char, pos): (56.10%, 156.64 pix^2)
# Epoch 131/200 - Train (char, pos): (99.51%, 59.40 pix^2)  Validation (char, pos): (55.89%, 152.35 pix^2)
# Epoch 132/200 - Train (char, pos): (99.50%, 58.51 pix^2)  Validation (char, pos): (55.35%, 157.15 pix^2)
# Epoch 133/200 - Train (char, pos): (99.49%, 57.88 pix^2)  Validation (char, pos): (55.83%, 154.01 pix^2)
# Epoch 134/200 - Train (char, pos): (95.73%, 70.07 pix^2)  Validation (char, pos): (46.55%, 182.87 pix^2)
# Epoch 135/200 - Train (char, pos): (93.18%, 84.72 pix^2)  Validation (char, pos): (52.59%, 154.46 pix^2)
# Epoch 136/200 - Train (char, pos): (96.93%, 73.38 pix^2)  Validation (char, pos): (55.21%, 148.77 pix^2)
# Epoch 137/200 - Train (char, pos): (98.49%, 67.31 pix^2)  Validation (char, pos): (56.13%, 149.82 pix^2)
# Epoch 138/200 - Train (char, pos): (99.08%, 64.15 pix^2)  Validation (char, pos): (56.73%, 153.21 pix^2)
# Epoch 139/200 - Train (char, pos): (99.24%, 62.10 pix^2)  Validation (char, pos): (56.36%, 149.12 pix^2)
# Epoch 140/200 - Train (char, pos): (99.36%, 60.94 pix^2)  Validation (char, pos): (56.52%, 151.22 pix^2)
# Epoch 141/200 - Train (char, pos): (99.43%, 59.82 pix^2)  Validation (char, pos): (56.93%, 156.43 pix^2)
# Epoch 142/200 - Train (char, pos): (88.11%, 105.00 pix^2)  Validation (char, pos): (52.84%, 157.35 pix^2)
# Epoch 143/200 - Train (char, pos): (96.67%, 79.13 pix^2)  Validation (char, pos): (54.38%, 153.37 pix^2)
# Epoch 144/200 - Train (char, pos): (98.22%, 72.96 pix^2)  Validation (char, pos): (55.79%, 150.47 pix^2)
# Epoch 145/200 - Train (char, pos): (98.91%, 67.20 pix^2)  Validation (char, pos): (55.56%, 153.94 pix^2)
# Epoch 146/200 - Train (char, pos): (99.11%, 64.87 pix^2)  Validation (char, pos): (55.82%, 153.15 pix^2)
# Epoch 147/200 - Train (char, pos): (99.25%, 63.23 pix^2)  Validation (char, pos): (55.95%, 150.93 pix^2)
# Epoch 148/200 - Train (char, pos): (99.34%, 61.72 pix^2)  Validation (char, pos): (56.52%, 150.52 pix^2)
# Epoch 149/200 - Train (char, pos): (99.42%, 60.56 pix^2)  Validation (char, pos): (55.95%, 153.03 pix^2)
# Epoch 150/200 - Train (char, pos): (99.46%, 59.36 pix^2)  Validation (char, pos): (56.20%, 152.11 pix^2)
# Epoch 151/200 - Train (char, pos): (99.48%, 58.61 pix^2)  Validation (char, pos): (56.56%, 150.24 pix^2)
# Epoch 152/200 - Train (char, pos): (99.54%, 57.41 pix^2)  Validation (char, pos): (55.80%, 153.23 pix^2)
# Epoch 153/200 - Train (char, pos): (99.53%, 56.71 pix^2)  Validation (char, pos): (55.81%, 155.37 pix^2)
# Epoch 154/200 - Train (char, pos): (99.55%, 55.85 pix^2)  Validation (char, pos): (55.65%, 152.56 pix^2)
# Epoch 155/200 - Train (char, pos): (99.34%, 56.71 pix^2)  Validation (char, pos): (51.84%, 153.56 pix^2)
# Epoch 156/200 - Train (char, pos): (89.87%, 89.70 pix^2)  Validation (char, pos): (52.27%, 154.58 pix^2)
# Epoch 157/200 - Train (char, pos): (97.29%, 73.66 pix^2)  Validation (char, pos): (54.45%, 151.86 pix^2)
# Epoch 158/200 - Train (char, pos): (98.71%, 66.26 pix^2)  Validation (char, pos): (55.08%, 144.68 pix^2)
# Epoch 159/200 - Train (char, pos): (99.03%, 63.51 pix^2)  Validation (char, pos): (55.40%, 145.78 pix^2)
# Epoch 160/200 - Train (char, pos): (99.23%, 61.33 pix^2)  Validation (char, pos): (55.56%, 146.58 pix^2)
# Epoch 161/200 - Train (char, pos): (99.35%, 60.01 pix^2)  Validation (char, pos): (55.50%, 147.42 pix^2)
# Epoch 162/200 - Train (char, pos): (99.42%, 58.56 pix^2)  Validation (char, pos): (55.71%, 148.13 pix^2)
# Epoch 163/200 - Train (char, pos): (99.46%, 57.46 pix^2)  Validation (char, pos): (56.02%, 149.18 pix^2)
# Epoch 164/200 - Train (char, pos): (99.50%, 56.55 pix^2)  Validation (char, pos): (55.48%, 150.29 pix^2)
# Epoch 165/200 - Train (char, pos): (99.54%, 55.58 pix^2)  Validation (char, pos): (56.08%, 149.54 pix^2)
# Epoch 166/200 - Train (char, pos): (99.56%, 54.70 pix^2)  Validation (char, pos): (55.84%, 149.42 pix^2)
# Epoch 167/200 - Train (char, pos): (99.58%, 53.94 pix^2)  Validation (char, pos): (56.03%, 152.49 pix^2)
# Epoch 168/200 - Train (char, pos): (99.58%, 53.32 pix^2)  Validation (char, pos): (56.04%, 149.49 pix^2)
# Epoch 169/200 - Train (char, pos): (99.59%, 52.68 pix^2)  Validation (char, pos): (55.91%, 149.59 pix^2)
# Epoch 170/200 - Train (char, pos): (88.16%, 88.89 pix^2)  Validation (char, pos): (46.98%, 165.83 pix^2)
# Epoch 171/200 - Train (char, pos): (91.28%, 89.28 pix^2)  Validation (char, pos): (53.74%, 150.95 pix^2)
# Epoch 172/200 - Train (char, pos): (97.44%, 70.20 pix^2)  Validation (char, pos): (54.62%, 150.51 pix^2)
# Epoch 173/200 - Train (char, pos): (98.47%, 65.60 pix^2)  Validation (char, pos): (55.14%, 149.39 pix^2)
# Epoch 174/200 - Train (char, pos): (98.85%, 62.96 pix^2)  Validation (char, pos): (55.86%, 149.48 pix^2)
# Epoch 175/200 - Train (char, pos): (99.04%, 61.25 pix^2)  Validation (char, pos): (55.92%, 150.86 pix^2)
# Epoch 176/200 - Train (char, pos): (99.20%, 59.54 pix^2)  Validation (char, pos): (55.50%, 153.09 pix^2)
# Epoch 177/200 - Train (char, pos): (99.31%, 58.54 pix^2)  Validation (char, pos): (55.80%, 155.09 pix^2)
# Epoch 178/200 - Train (char, pos): (99.36%, 57.45 pix^2)  Validation (char, pos): (55.97%, 153.53 pix^2)
# Epoch 179/200 - Train (char, pos): (99.42%, 56.24 pix^2)  Validation (char, pos): (56.11%, 152.13 pix^2)
# Epoch 180/200 - Train (char, pos): (99.47%, 55.47 pix^2)  Validation (char, pos): (56.46%, 152.33 pix^2)
# Epoch 181/200 - Train (char, pos): (99.52%, 54.58 pix^2)  Validation (char, pos): (56.39%, 153.43 pix^2)
# Epoch 182/200 - Train (char, pos): (99.55%, 53.64 pix^2)  Validation (char, pos): (56.52%, 152.02 pix^2)
# Epoch 183/200 - Train (char, pos): (99.56%, 52.96 pix^2)  Validation (char, pos): (56.24%, 154.83 pix^2)
# Epoch 184/200 - Train (char, pos): (99.59%, 52.20 pix^2)  Validation (char, pos): (56.45%, 151.81 pix^2)
# Epoch 185/200 - Train (char, pos): (99.61%, 51.40 pix^2)  Validation (char, pos): (56.07%, 153.17 pix^2)
# Epoch 186/200 - Train (char, pos): (91.06%, 82.08 pix^2)  Validation (char, pos): (53.22%, 148.40 pix^2)
# Epoch 187/200 - Train (char, pos): (94.45%, 74.62 pix^2)  Validation (char, pos): (53.45%, 148.88 pix^2)
# Epoch 188/200 - Train (char, pos): (98.34%, 64.32 pix^2)  Validation (char, pos): (55.13%, 145.79 pix^2)
# Epoch 189/200 - Train (char, pos): (98.96%, 60.41 pix^2)  Validation (char, pos): (55.15%, 152.86 pix^2)
# Epoch 190/200 - Train (char, pos): (99.17%, 58.28 pix^2)  Validation (char, pos): (55.05%, 151.30 pix^2)
# Epoch 191/200 - Train (char, pos): (99.31%, 56.75 pix^2)  Validation (char, pos): (55.50%, 149.86 pix^2)
# Epoch 192/200 - Train (char, pos): (99.39%, 55.60 pix^2)  Validation (char, pos): (55.25%, 151.12 pix^2)
# Epoch 193/200 - Train (char, pos): (99.44%, 54.48 pix^2)  Validation (char, pos): (55.18%, 150.37 pix^2)
# Epoch 194/200 - Train (char, pos): (99.51%, 53.73 pix^2)  Validation (char, pos): (55.70%, 151.56 pix^2)
# Epoch 195/200 - Train (char, pos): (99.54%, 52.79 pix^2)  Validation (char, pos): (55.93%, 151.45 pix^2)
# Epoch 196/200 - Train (char, pos): (99.58%, 51.89 pix^2)  Validation (char, pos): (55.76%, 152.07 pix^2)
# Epoch 197/200 - Train (char, pos): (99.59%, 51.41 pix^2)  Validation (char, pos): (55.86%, 151.23 pix^2)
# Epoch 198/200 - Train (char, pos): (99.60%, 50.56 pix^2)  Validation (char, pos): (55.64%, 155.47 pix^2)
# Epoch 199/200 - Train (char, pos): (99.62%, 50.13 pix^2)  Validation (char, pos): (56.35%, 150.30 pix^2)
# Epoch 200/200 - Train (char, pos): (99.64%, 49.50 pix^2)  Validation (char, pos): (55.99%, 150.58 pix^2)

# %%
# 绘制 accuracy 曲线（坐标预测版本）
if 'results_rnn' in locals():
    plt.figure(figsize=(12, 5))
    
    # 字符准确率曲线
    plt.subplot(1, 2, 1)
    plt.plot(results_rnn['train_acc_char'], label='train char acc', marker='o', markersize=3)
    plt.plot(results_rnn['val_acc_char'], label='val char acc', marker='s', markersize=3)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.title('Character Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 位置 MSE 曲线
    plt.subplot(1, 2, 2)
    plt.plot(results_rnn['train_err_pos'], label='train pos MSE', marker='o', markersize=3)
    plt.plot(results_rnn['val_err_pos'], label='val pos MSE', marker='s', markersize=3)
    plt.xlabel('Epoch')
    plt.ylabel('MSE (pixel^2)')
    plt.title('Position Error (MSE)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # 打印最终结果
    print(f"Final Training Character Accuracy: {results_rnn['train_acc_char'][-1]:.2f}%")
    print(f"Final Validation Character Accuracy: {results_rnn['val_acc_char'][-1]:.2f}%")
    print(f"Final Training Position MSE: {results_rnn['train_err_pos'][-1]:.4f} pixel^2")
    print(f"Final Validation Position MSE: {results_rnn['val_err_pos'][-1]:.4f} pixel^2")
else:
    print("results_rnn not found. Please run the training cell first.")
# Out:
# Final Training Character Accuracy: 99.64%
# Final Validation Character Accuracy: 55.99%
# Final Training Position MSE: 49.4959 pixel^2
# Final Validation Position MSE: 150.5792 pixel^2

# %%
params = list(mdl_rnn.rnn.parameters())[1].cpu().detach().numpy()
plt.imshow(params[:100,:100])

# %%
U,S,V = np.linalg.svd(params, full_matrices=False)

# %% [markdown]
# ## Two-layer stacked RNN

# %%
# Create dataset class for loading stacks of frames as multichannel images
# for use in testing the performance of recurrent models
class RNNConvStack(nn.Module):
    def __init__(self, num_classes, num_pos, kernel_size=3, device='cuda'):
        super(RNNConvStack, self).__init__()
        self.device = device
        self.conv1 = nn.Conv2d(2, 32, kernel_size=kernel_size, padding='same')
        self.MP1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.LNorm1 = nn.LayerNorm([32, 48, 48])
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.MP2 = nn.MaxPool2d(kernel_size=4, stride=4)
        self.LNorm2 = nn.LayerNorm([64, 12, 12])
        self.rnn = nn.RNN(input_size=64 * 12 * 12, hidden_size=240, 
                          num_layers=2, batch_first=True, dropout=0.5)
        self.LNormRNN = nn.LayerNorm(240)
        self.fcchar = nn.Linear(240, num_classes)
        self.fcpos = nn.Linear(240, num_pos)
        self.to(self.device)

    def encoder(self, x):
        return nn.Sequential(
            self.conv1,
            self.MP1,
            self.LNorm1,
            nn.ReLU(),
            self.conv2,
            self.MP2,
            self.LNorm2,
            nn.ReLU()
        )(x)

    def middle(self, x):
        x = self.rnn(x)[0]
        x = self.LNormRNN(x)
        x = nn.Dropout(0.5)(nn.ReLU()(x))
        return x

    def classifier(self, x):
        return self.fcchar(x), self.fcpos(x)

    def forward(self, x):
        x = x.to(self.device)

        batch_size, frame_num, channels, height, width = x.size()

        # resize to process each frame individually
        x = x.view(batch_size * frame_num, channels, height, width)

        # apply CNN encoder
        x = self.encoder(x)
        
        # reshape back to batches of stacks of frames and flatten each image
        x = x.view(batch_size, frame_num, -1)

        # apply RNN
        x = self.middle(x)

        # apply classification heads
        char_out, pos_out = self.classifier(x)
        return char_out, pos_out

# %%
stim_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.npy"
label_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.tsv"
stims_train = np.load(stim_train_path, allow_pickle=True)
lbls_train = pd.read_csv(label_train_path, sep="\t", index_col=0)

stim_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.npy"
label_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.tsv"
stims_val = np.load(stim_val_path, allow_pickle=True)
lbls_val = pd.read_csv(label_val_path, sep="\t", index_col=0)


train_ds = MC_RNN_Dataset(stims_train, lbls_train)
val_ds = MC_RNN_Dataset(stims_val, lbls_val)
mdl_rnn = RNNConvStack(num_classes=10, num_pos=2, kernel_size=5)
print(f"RNN model parameter count: {model_param_count(mdl_rnn)}")
results_rnn = network_train(mdl_rnn, train_ds, val_ds, num_epochs=50, loss_weights=[1.0, 0.001])
# Out:
# RNN model parameter count: 2574988
# Epoch 1/50 - Train (char, pos): (10.17%, 1044.88 pix^2)  Validation (char, pos): (9.93%, 437.34 pix^2)
# Epoch 2/50 - Train (char, pos): (10.33%, 381.28 pix^2)  Validation (char, pos): (10.55%, 333.24 pix^2)
# Epoch 3/50 - Train (char, pos): (10.48%, 261.57 pix^2)  Validation (char, pos): (11.30%, 184.40 pix^2)
# Epoch 4/50 - Train (char, pos): (10.31%, 189.89 pix^2)  Validation (char, pos): (9.89%, 159.15 pix^2)
# Epoch 5/50 - Train (char, pos): (13.64%, 167.69 pix^2)  Validation (char, pos): (17.55%, 156.85 pix^2)
# Epoch 6/50 - Train (char, pos): (19.28%, 162.05 pix^2)  Validation (char, pos): (20.49%, 145.13 pix^2)
# Epoch 7/50 - Train (char, pos): (21.94%, 151.61 pix^2)  Validation (char, pos): (20.92%, 136.54 pix^2)
# Epoch 8/50 - Train (char, pos): (24.22%, 151.23 pix^2)  Validation (char, pos): (23.73%, 138.65 pix^2)
# Epoch 9/50 - Train (char, pos): (27.50%, 141.90 pix^2)  Validation (char, pos): (28.30%, 133.79 pix^2)
# Epoch 10/50 - Train (char, pos): (31.24%, 138.61 pix^2)  Validation (char, pos): (28.10%, 136.27 pix^2)
# Epoch 11/50 - Train (char, pos): (35.19%, 139.55 pix^2)  Validation (char, pos): (33.85%, 135.45 pix^2)
# Epoch 12/50 - Train (char, pos): (38.94%, 135.23 pix^2)  Validation (char, pos): (36.06%, 135.10 pix^2)
# Epoch 13/50 - Train (char, pos): (41.81%, 133.88 pix^2)  Validation (char, pos): (37.59%, 135.39 pix^2)
# Epoch 14/50 - Train (char, pos): (44.32%, 133.40 pix^2)  Validation (char, pos): (35.77%, 146.29 pix^2)
# Epoch 15/50 - Train (char, pos): (48.98%, 132.26 pix^2)  Validation (char, pos): (40.86%, 133.89 pix^2)
# Epoch 16/50 - Train (char, pos): (51.98%, 130.40 pix^2)  Validation (char, pos): (40.99%, 141.06 pix^2)
# Epoch 17/50 - Train (char, pos): (53.28%, 129.80 pix^2)  Validation (char, pos): (36.24%, 132.20 pix^2)
# Epoch 18/50 - Train (char, pos): (56.96%, 129.14 pix^2)  Validation (char, pos): (43.89%, 142.32 pix^2)
# Epoch 19/50 - Train (char, pos): (60.53%, 127.93 pix^2)  Validation (char, pos): (44.64%, 143.38 pix^2)
# Epoch 20/50 - Train (char, pos): (61.27%, 130.89 pix^2)  Validation (char, pos): (46.01%, 147.57 pix^2)
# Epoch 21/50 - Train (char, pos): (63.62%, 129.34 pix^2)  Validation (char, pos): (45.59%, 140.01 pix^2)
# Epoch 22/50 - Train (char, pos): (63.43%, 133.00 pix^2)  Validation (char, pos): (46.11%, 142.30 pix^2)
# Epoch 23/50 - Train (char, pos): (67.13%, 130.37 pix^2)  Validation (char, pos): (47.25%, 142.31 pix^2)
# Epoch 24/50 - Train (char, pos): (69.09%, 129.04 pix^2)  Validation (char, pos): (46.89%, 141.01 pix^2)
# Epoch 25/50 - Train (char, pos): (69.81%, 128.92 pix^2)  Validation (char, pos): (47.05%, 146.63 pix^2)
# Epoch 26/50 - Train (char, pos): (72.34%, 126.76 pix^2)  Validation (char, pos): (47.97%, 144.00 pix^2)
# Epoch 27/50 - Train (char, pos): (72.42%, 127.76 pix^2)  Validation (char, pos): (49.14%, 145.04 pix^2)
# Epoch 28/50 - Train (char, pos): (75.66%, 125.90 pix^2)  Validation (char, pos): (48.35%, 138.80 pix^2)
# Epoch 29/50 - Train (char, pos): (72.70%, 127.31 pix^2)  Validation (char, pos): (36.52%, 173.39 pix^2)
# Epoch 30/50 - Train (char, pos): (73.69%, 130.82 pix^2)  Validation (char, pos): (47.53%, 138.83 pix^2)
# Epoch 31/50 - Train (char, pos): (76.41%, 126.17 pix^2)  Validation (char, pos): (46.44%, 142.52 pix^2)
# Epoch 32/50 - Train (char, pos): (76.37%, 127.84 pix^2)  Validation (char, pos): (47.29%, 142.58 pix^2)
# Epoch 33/50 - Train (char, pos): (77.23%, 127.15 pix^2)  Validation (char, pos): (49.41%, 145.53 pix^2)
# Epoch 34/50 - Train (char, pos): (78.19%, 127.13 pix^2)  Validation (char, pos): (47.93%, 144.26 pix^2)
# Epoch 35/50 - Train (char, pos): (75.87%, 129.29 pix^2)  Validation (char, pos): (46.89%, 148.69 pix^2)
# Epoch 36/50 - Train (char, pos): (81.27%, 124.80 pix^2)  Validation (char, pos): (47.35%, 145.68 pix^2)
# Epoch 37/50 - Train (char, pos): (74.89%, 130.88 pix^2)  Validation (char, pos): (47.53%, 146.40 pix^2)
# Epoch 38/50 - Train (char, pos): (81.82%, 124.68 pix^2)  Validation (char, pos): (48.36%, 144.03 pix^2)
# Epoch 39/50 - Train (char, pos): (79.97%, 125.26 pix^2)  Validation (char, pos): (44.27%, 146.09 pix^2)
# Epoch 40/50 - Train (char, pos): (82.62%, 123.55 pix^2)  Validation (char, pos): (48.41%, 141.25 pix^2)
# Epoch 41/50 - Train (char, pos): (84.88%, 121.31 pix^2)  Validation (char, pos): (47.49%, 145.43 pix^2)
# Epoch 42/50 - Train (char, pos): (86.18%, 120.39 pix^2)  Validation (char, pos): (49.92%, 141.87 pix^2)
# Epoch 43/50 - Train (char, pos): (83.73%, 122.98 pix^2)  Validation (char, pos): (49.04%, 147.65 pix^2)
# Epoch 44/50 - Train (char, pos): (79.61%, 128.30 pix^2)  Validation (char, pos): (47.06%, 145.82 pix^2)
# Epoch 45/50 - Train (char, pos): (85.78%, 121.40 pix^2)  Validation (char, pos): (48.52%, 146.06 pix^2)
# Epoch 46/50 - Train (char, pos): (85.75%, 121.41 pix^2)  Validation (char, pos): (46.94%, 146.72 pix^2)
# Epoch 47/50 - Train (char, pos): (85.71%, 121.19 pix^2)  Validation (char, pos): (48.43%, 146.15 pix^2)
# Epoch 48/50 - Train (char, pos): (82.24%, 124.74 pix^2)  Validation (char, pos): (44.22%, 149.57 pix^2)
# Epoch 49/50 - Train (char, pos): (82.23%, 124.28 pix^2)  Validation (char, pos): (48.89%, 143.86 pix^2)
# Epoch 50/50 - Train (char, pos): (88.41%, 119.50 pix^2)  Validation (char, pos): (49.39%, 141.85 pix^2)

# %% [markdown]
# ## Split RNN, split classification
# RNNs are separated into distinct classification channels

# %%
# Create dataset class for loading stacks of frames as multichannel images
# for use in testing the performance of recurrent models
class RNNConvSplitDisc(nn.Module):
    def __init__(self, num_classes, num_pos, kernel_size=3, device='cuda'):
        super(RNNConvSplitDisc, self).__init__()
        self.device = device
        self.conv1 = nn.Conv2d(2, 32, kernel_size=kernel_size, padding='same')
        self.MP1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.LNorm1 = nn.LayerNorm([32, 48, 48])
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.MP2 = nn.MaxPool2d(kernel_size=4, stride=4)
        self.LNorm2 = nn.LayerNorm([64, 12, 12])
        self.rnnchar = nn.RNN(input_size=64 * 12 * 12, hidden_size=128, 
                          num_layers=1, batch_first=True)
        self.rnnpos = nn.RNN(input_size=64 * 12 * 12, hidden_size=128, 
                          num_layers=1, batch_first=True)
        self.LNormRNNPos = nn.LayerNorm(128)
        self.LNormRNNChar = nn.LayerNorm(128)
        self.fcchar = nn.Linear(128, num_classes)
        self.fcpos = nn.Linear(128, num_pos)
        self.to(self.device)

    def encoder(self, x):
        return nn.Sequential(
            self.conv1,
            self.MP1,
            self.LNorm1,
            nn.ReLU(),
            self.conv2,
            self.MP2,
            self.LNorm2,
            nn.ReLU()
        )(x)

    def middle(self, x):
        xchar = self.rnnchar(x)[0]
        xpos = self.rnnpos(x)[0]
        xchar = self.LNormRNNChar(xchar)
        xpos = self.LNormRNNPos(xpos)
        xchar = nn.Dropout(0.5)(nn.ReLU()(xchar))
        xpos = nn.Dropout(0.5)(nn.ReLU()(xpos))
        return xchar, xpos

    def classifier(self, xc, xp):
        return self.fcchar(xc), self.fcpos(xp)

    def forward(self, x):
        x = x.to(self.device)

        batch_size, frame_num, channels, height, width = x.size()

        # resize to process each frame individually
        x = x.view(batch_size * frame_num, channels, height, width)

        # apply CNN encoder
        x = self.encoder(x)
        
        # reshape back to batches of stacks of frames and flatten each image
        x = x.view(batch_size, frame_num, -1)

        # apply RNN
        xc, xp = self.middle(x)

        # apply classification heads
        char_out, pos_out = self.classifier(xc, xp)
        return char_out, pos_out

# %%
stim_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.npy"
label_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.tsv"
stims_train = np.load(stim_train_path, allow_pickle=True)
lbls_train = pd.read_csv(label_train_path, sep="\t", index_col=0)

stim_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.npy"
label_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.tsv"
stims_val = np.load(stim_val_path, allow_pickle=True)
lbls_val = pd.read_csv(label_val_path, sep="\t", index_col=0)


train_ds = MC_RNN_Dataset(stims_train, lbls_train)
val_ds = MC_RNN_Dataset(stims_val, lbls_val)
mdl_rnn = RNNConvSplitDisc(num_classes=10, num_pos=2, kernel_size=5)
print(f"RNN model parameter count: {model_param_count(mdl_rnn)}")
results_rnn = network_train(mdl_rnn, train_ds, val_ds, num_epochs=50, loss_weights=[1.0, 0.001])
# Out:
# RNN model parameter count: 2580652
# Epoch 1/50 - Train (char, pos): (10.36%, 1399.52 pix^2)  Validation (char, pos): (10.49%, 614.85 pix^2)
# Epoch 2/50 - Train (char, pos): (11.01%, 461.18 pix^2)  Validation (char, pos): (10.44%, 428.46 pix^2)
# Epoch 3/50 - Train (char, pos): (12.67%, 381.31 pix^2)  Validation (char, pos): (13.81%, 339.84 pix^2)
# Epoch 4/50 - Train (char, pos): (18.04%, 295.52 pix^2)  Validation (char, pos): (16.14%, 271.65 pix^2)
# Epoch 5/50 - Train (char, pos): (20.53%, 246.13 pix^2)  Validation (char, pos): (21.47%, 216.93 pix^2)
# Epoch 6/50 - Train (char, pos): (25.78%, 206.18 pix^2)  Validation (char, pos): (26.76%, 189.22 pix^2)
# Epoch 7/50 - Train (char, pos): (29.89%, 184.58 pix^2)  Validation (char, pos): (29.54%, 177.54 pix^2)
# Epoch 8/50 - Train (char, pos): (35.29%, 168.03 pix^2)  Validation (char, pos): (34.12%, 161.81 pix^2)
# Epoch 9/50 - Train (char, pos): (41.45%, 154.15 pix^2)  Validation (char, pos): (35.79%, 165.53 pix^2)
# Epoch 10/50 - Train (char, pos): (46.29%, 147.47 pix^2)  Validation (char, pos): (42.03%, 151.95 pix^2)
# Epoch 11/50 - Train (char, pos): (51.82%, 133.11 pix^2)  Validation (char, pos): (45.33%, 147.25 pix^2)
# Epoch 12/50 - Train (char, pos): (51.20%, 136.57 pix^2)  Validation (char, pos): (43.80%, 149.24 pix^2)
# Epoch 13/50 - Train (char, pos): (58.16%, 121.00 pix^2)  Validation (char, pos): (43.85%, 144.76 pix^2)
# Epoch 14/50 - Train (char, pos): (60.24%, 114.41 pix^2)  Validation (char, pos): (47.45%, 140.16 pix^2)
# Epoch 15/50 - Train (char, pos): (63.30%, 118.69 pix^2)  Validation (char, pos): (46.21%, 141.71 pix^2)
# Epoch 16/50 - Train (char, pos): (65.88%, 106.18 pix^2)  Validation (char, pos): (47.67%, 144.55 pix^2)
# Epoch 17/50 - Train (char, pos): (62.15%, 138.27 pix^2)  Validation (char, pos): (48.21%, 139.90 pix^2)
# Epoch 18/50 - Train (char, pos): (70.90%, 103.06 pix^2)  Validation (char, pos): (49.47%, 137.72 pix^2)
# Epoch 19/50 - Train (char, pos): (73.54%, 97.56 pix^2)  Validation (char, pos): (49.37%, 143.00 pix^2)
# Epoch 20/50 - Train (char, pos): (75.54%, 95.55 pix^2)  Validation (char, pos): (46.05%, 151.41 pix^2)
# Epoch 21/50 - Train (char, pos): (72.66%, 95.59 pix^2)  Validation (char, pos): (47.63%, 141.78 pix^2)
# Epoch 22/50 - Train (char, pos): (77.30%, 89.63 pix^2)  Validation (char, pos): (50.13%, 141.57 pix^2)
# Epoch 23/50 - Train (char, pos): (73.62%, 92.73 pix^2)  Validation (char, pos): (50.62%, 136.86 pix^2)
# Epoch 24/50 - Train (char, pos): (78.69%, 87.46 pix^2)  Validation (char, pos): (50.26%, 148.33 pix^2)
# Epoch 25/50 - Train (char, pos): (79.83%, 85.30 pix^2)  Validation (char, pos): (47.41%, 141.29 pix^2)
# Epoch 26/50 - Train (char, pos): (80.18%, 84.49 pix^2)  Validation (char, pos): (39.74%, 159.71 pix^2)
# Epoch 27/50 - Train (char, pos): (75.31%, 96.19 pix^2)  Validation (char, pos): (51.76%, 142.20 pix^2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 16
#      14 mdl_rnn = RNNConvSplitDisc(num_classes=10, num_pos=2, kernel_size=5)
#      15 print(f"RNN model parameter count: {model_param_count(mdl_rnn)}")
# ---> 16 results_rnn = network_train(mdl_rnn, train_ds, val_ds, num_epochs=50, loss_weights=[1.0, 0.001])
#
# Cell In[5], line 41, in network_train(mdl, train_data, val_data, num_epochs, loss_weights, lr)
#      39 for epoch in range(num_epochs):
#      40     mdl.train()
# ---> 41     for batch in train_dl:
#      42         inputs, labels = batch
#      43         labels = labels.to(mdl.device)
#
# File c:\Users\dbh60\.conda\envs\rnn_env\Lib\site-packages\torch\utils\data\dataloader.py:729, in _BaseDataLoaderIter.__next__(self)
#     728 def __next__(self) -> Any:
# --> 729     with torch.autograd.profiler.record_function(self._profile_name):
#     730         if self._sampler_iter is None:
#     731             # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732             self._reset()  # type: ignore[call-arg]
#
# File c:\Users\dbh60\.conda\envs\rnn_env\Lib\site-packages\torch\autograd\profiler.py:788, in record_function.__exit__(self, exc_type, exc_value, traceback)
#     786 if not torch.jit.is_scripting():
#     787     with torch._C.DisableTorchFunctionSubclass():
# --> 788         torch.ops.profiler._record_function_exit._RecordFunction(record)
#     789 else:
#     790     torch.ops.profiler._record_function_exit(record)
#
# File c:\Users\dbh60\.conda\envs\rnn_env\Lib\site-packages\torch\_ops.py:995, in TorchBindOpOverload.__call__(self, *args, **kwargs)
#     993     with self._register_as_effectful_op_temporarily():
#     994         return self._dispatch_in_python(args, kwargs, self._fallthrough_keys())
# --> 995 return self._op(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Split RNN, shared classification
# One for character, the other for position

# %%
# Create dataset class for loading stacks of frames as multichannel images
# for use in testing the performance of recurrent models
class RNNConvSplit(nn.Module):
    def __init__(self, num_classes, num_pos, kernel_size=3, device='cuda'):
        super(RNNConvSplit, self).__init__()
        self.device = device
        self.conv1 = nn.Conv2d(2, 32, kernel_size=kernel_size, padding='same')
        self.MP1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.LNorm1 = nn.LayerNorm([32, 48, 48])
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.MP2 = nn.MaxPool2d(kernel_size=4, stride=4)
        self.LNorm2 = nn.LayerNorm([64, 12, 12])
        self.rnnchar = nn.RNN(input_size=64 * 12 * 12, hidden_size=128, 
                          num_layers=1, batch_first=True)
        self.rnnpos = nn.RNN(input_size=64 * 12 * 12, hidden_size=128, 
                          num_layers=1, batch_first=True)
        self.LNormRNN = nn.LayerNorm(256)
        self.fcchar = nn.Linear(256, num_classes)
        self.fcpos = nn.Linear(256, num_pos)
        self.to(self.device)

    def encoder(self, x):
        return nn.Sequential(
            self.conv1,
            self.MP1,
            self.LNorm1,
            nn.ReLU(),
            self.conv2,
            self.MP2,
            self.LNorm2,
            nn.ReLU()
        )(x)

    def middle(self, x):
        xchar = self.rnnchar(x)[0]
        xpos = self.rnnpos(x)[0]
        x = torch.cat((xchar, xpos), dim=2)
        x = self.LNormRNN(x)
        x = nn.Dropout(0.5)(nn.ReLU()(x))
        return x

    def classifier(self, x):
        return self.fcchar(x), self.fcpos(x)

    def forward(self, x):
        x = x.to(self.device)

        batch_size, frame_num, channels, height, width = x.size()

        # resize to process each frame individually
        x = x.view(batch_size * frame_num, channels, height, width)

        # apply CNN encoder
        x = self.encoder(x)
        
        # reshape back to batches of stacks of frames and flatten each image
        x = x.view(batch_size, frame_num, -1)

        # apply RNN
        x = self.middle(x)

        # apply classification heads
        char_out, pos_out = self.classifier(x)
        return char_out, pos_out

# %%
stim_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.npy"
label_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.tsv"
stims_train = np.load(stim_train_path, allow_pickle=True)
lbls_train = pd.read_csv(label_train_path, sep="\t", index_col=0)

stim_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.npy"
label_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.tsv"
stims_val = np.load(stim_val_path, allow_pickle=True)
lbls_val = pd.read_csv(label_val_path, sep="\t", index_col=0)


train_ds = MC_RNN_Dataset(stims_train, lbls_train)
val_ds = MC_RNN_Dataset(stims_val, lbls_val)
mdl_rnn = RNNConvSplit(num_classes=10, num_pos=2, kernel_size=5)
results_rnn = network_train(mdl_rnn, train_ds, val_ds, num_epochs=50, loss_weights=[1.0, 0.001])
# Out:
# Epoch 1/50 - Train (char, pos): (10.28%, 1007.72 pix^2)  Validation (char, pos): (9.53%, 408.06 pix^2)
# Epoch 2/50 - Train (char, pos): (12.10%, 356.80 pix^2)  Validation (char, pos): (14.09%, 339.01 pix^2)
# Epoch 3/50 - Train (char, pos): (18.56%, 299.95 pix^2)  Validation (char, pos): (17.79%, 285.08 pix^2)
# Epoch 4/50 - Train (char, pos): (24.43%, 266.72 pix^2)  Validation (char, pos): (25.65%, 258.40 pix^2)
# Epoch 5/50 - Train (char, pos): (32.65%, 246.95 pix^2)  Validation (char, pos): (32.47%, 236.49 pix^2)
# Epoch 6/50 - Train (char, pos): (41.55%, 226.74 pix^2)  Validation (char, pos): (39.48%, 220.59 pix^2)
# Epoch 7/50 - Train (char, pos): (49.09%, 209.48 pix^2)  Validation (char, pos): (42.83%, 212.25 pix^2)
# Epoch 8/50 - Train (char, pos): (56.56%, 194.53 pix^2)  Validation (char, pos): (45.95%, 202.17 pix^2)
# Epoch 9/50 - Train (char, pos): (62.79%, 186.15 pix^2)  Validation (char, pos): (47.67%, 199.44 pix^2)
# Epoch 10/50 - Train (char, pos): (68.38%, 178.92 pix^2)  Validation (char, pos): (47.92%, 194.24 pix^2)
# Epoch 11/50 - Train (char, pos): (72.88%, 171.71 pix^2)  Validation (char, pos): (49.32%, 195.12 pix^2)
# Epoch 12/50 - Train (char, pos): (76.95%, 166.40 pix^2)  Validation (char, pos): (51.49%, 189.51 pix^2)
# Epoch 13/50 - Train (char, pos): (80.14%, 161.87 pix^2)  Validation (char, pos): (52.08%, 186.68 pix^2)
# Epoch 14/50 - Train (char, pos): (83.97%, 156.43 pix^2)  Validation (char, pos): (51.93%, 185.48 pix^2)
# Epoch 15/50 - Train (char, pos): (85.36%, 154.00 pix^2)  Validation (char, pos): (52.37%, 184.82 pix^2)
# Epoch 16/50 - Train (char, pos): (88.33%, 148.16 pix^2)  Validation (char, pos): (53.07%, 183.20 pix^2)
# Epoch 17/50 - Train (char, pos): (88.06%, 149.09 pix^2)  Validation (char, pos): (51.26%, 186.83 pix^2)
# Epoch 18/50 - Train (char, pos): (90.20%, 145.03 pix^2)  Validation (char, pos): (51.31%, 181.82 pix^2)
# Epoch 19/50 - Train (char, pos): (90.85%, 141.85 pix^2)  Validation (char, pos): (52.97%, 180.78 pix^2)
# Epoch 20/50 - Train (char, pos): (92.86%, 138.13 pix^2)  Validation (char, pos): (53.17%, 177.68 pix^2)
# Epoch 21/50 - Train (char, pos): (91.63%, 138.67 pix^2)  Validation (char, pos): (50.12%, 185.85 pix^2)
# Epoch 22/50 - Train (char, pos): (89.52%, 142.06 pix^2)  Validation (char, pos): (53.16%, 178.73 pix^2)
# Epoch 23/50 - Train (char, pos): (94.53%, 132.14 pix^2)  Validation (char, pos): (54.09%, 177.65 pix^2)
# Epoch 24/50 - Train (char, pos): (95.84%, 126.56 pix^2)  Validation (char, pos): (53.98%, 175.51 pix^2)
# Epoch 25/50 - Train (char, pos): (96.37%, 123.53 pix^2)  Validation (char, pos): (53.51%, 176.03 pix^2)
# Epoch 26/50 - Train (char, pos): (95.36%, 123.22 pix^2)  Validation (char, pos): (52.13%, 180.55 pix^2)
# Epoch 27/50 - Train (char, pos): (84.55%, 147.03 pix^2)  Validation (char, pos): (50.83%, 184.76 pix^2)
# Epoch 28/50 - Train (char, pos): (94.60%, 127.80 pix^2)  Validation (char, pos): (53.47%, 180.08 pix^2)
# Epoch 29/50 - Train (char, pos): (96.44%, 121.09 pix^2)  Validation (char, pos): (53.73%, 175.97 pix^2)
# Epoch 30/50 - Train (char, pos): (96.69%, 118.72 pix^2)  Validation (char, pos): (53.12%, 176.17 pix^2)
# Epoch 31/50 - Train (char, pos): (94.44%, 122.99 pix^2)  Validation (char, pos): (51.13%, 190.90 pix^2)
# Epoch 32/50 - Train (char, pos): (92.03%, 129.40 pix^2)  Validation (char, pos): (52.16%, 186.59 pix^2)
# Epoch 33/50 - Train (char, pos): (93.07%, 127.37 pix^2)  Validation (char, pos): (52.27%, 177.64 pix^2)
# Epoch 34/50 - Train (char, pos): (96.79%, 117.47 pix^2)  Validation (char, pos): (53.38%, 173.05 pix^2)
# Epoch 35/50 - Train (char, pos): (97.55%, 112.98 pix^2)  Validation (char, pos): (53.69%, 172.16 pix^2)
# Epoch 36/50 - Train (char, pos): (97.78%, 109.92 pix^2)  Validation (char, pos): (53.77%, 173.02 pix^2)
# Epoch 37/50 - Train (char, pos): (97.97%, 107.63 pix^2)  Validation (char, pos): (53.40%, 171.73 pix^2)
# Epoch 38/50 - Train (char, pos): (97.89%, 107.44 pix^2)  Validation (char, pos): (53.67%, 168.85 pix^2)
# Epoch 39/50 - Train (char, pos): (98.13%, 105.25 pix^2)  Validation (char, pos): (53.29%, 167.02 pix^2)
# Epoch 40/50 - Train (char, pos): (86.85%, 132.02 pix^2)  Validation (char, pos): (49.15%, 182.72 pix^2)
# Epoch 41/50 - Train (char, pos): (93.56%, 120.92 pix^2)  Validation (char, pos): (52.72%, 172.91 pix^2)
# Epoch 42/50 - Train (char, pos): (96.88%, 111.82 pix^2)  Validation (char, pos): (53.33%, 173.18 pix^2)
# Epoch 43/50 - Train (char, pos): (97.60%, 107.43 pix^2)  Validation (char, pos): (53.91%, 169.32 pix^2)
# Epoch 44/50 - Train (char, pos): (96.50%, 110.01 pix^2)  Validation (char, pos): (52.67%, 172.77 pix^2)
# Epoch 45/50 - Train (char, pos): (97.49%, 107.85 pix^2)  Validation (char, pos): (53.41%, 170.30 pix^2)
# Epoch 46/50 - Train (char, pos): (93.73%, 114.12 pix^2)  Validation (char, pos): (50.43%, 178.53 pix^2)
# Epoch 47/50 - Train (char, pos): (96.13%, 111.13 pix^2)  Validation (char, pos): (52.81%, 168.03 pix^2)
# Epoch 48/50 - Train (char, pos): (97.97%, 104.13 pix^2)  Validation (char, pos): (53.57%, 165.71 pix^2)
# Epoch 49/50 - Train (char, pos): (98.02%, 101.71 pix^2)  Validation (char, pos): (53.93%, 166.45 pix^2)
# Epoch 50/50 - Train (char, pos): (98.40%, 99.38 pix^2)  Validation (char, pos): (53.51%, 164.92 pix^2)

# %% [markdown]
# ## Shared layer 1 RNN, split at layer 2

# %%
# Create dataset class for loading stacks of frames as multichannel images
# for use in testing the performance of recurrent models
class RNNConvShareSplit(nn.Module):
    def __init__(self, num_classes, num_pos, kernel_size=3, device='cuda'):
        super(RNNConvShareSplit, self).__init__()
        self.device = device
        self.conv1 = nn.Conv2d(2, 32, kernel_size=kernel_size, padding='same')
        self.MP1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.LNorm1 = nn.LayerNorm([32, 48, 48])
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.MP2 = nn.MaxPool2d(kernel_size=4, stride=4)
        self.LNorm2 = nn.LayerNorm([64, 12, 12])
        self.rnnshare = nn.RNN(input_size=64 * 12 * 12, hidden_size=128, 
                          num_layers=1, batch_first=True)
        self.rnnchar = nn.RNN(input_size=128, hidden_size=64, 
                          num_layers=1, batch_first=True)
        self.rnnpos = nn.RNN(input_size=128, hidden_size=64, 
                          num_layers=1, batch_first=True)
        self.LNormRNN = nn.LayerNorm(128)
        self.fcchar = nn.Linear(128, num_classes)
        self.fcpos = nn.Linear(128, num_pos)
        self.to(self.device)

    def encoder(self, x):
        return nn.Sequential(
            self.conv1,
            self.MP1,
            self.LNorm1,
            nn.ReLU(),
            self.conv2,
            self.MP2,
            self.LNorm2,
            nn.ReLU()
        )(x)

    def middle(self, x):
        x = self.rnnshare(x)[0]
        x = nn.Dropout(0.5)(nn.ReLU()(x))
        xchar = self.rnnchar(x)[0]
        xpos = self.rnnpos(x)[0]
        x = torch.cat((xchar, xpos), dim=2)
        x = self.LNormRNN(x)
        x = nn.Dropout(0.5)(nn.ReLU()(x))
        return x

    def classifier(self, x):
        return self.fcchar(x), self.fcpos(x)

    def forward(self, x):
        x = x.to(self.device)

        batch_size, frame_num, channels, height, width = x.size()

        # resize to process each frame individually
        x = x.view(batch_size * frame_num, channels, height, width)

        # apply CNN encoder
        x = self.encoder(x)
        
        # reshape back to batches of stacks of frames and flatten each image
        x = x.view(batch_size, frame_num, -1)

        # apply RNN
        x = self.middle(x)

        # apply classification heads
        char_out, pos_out = self.classifier(x)
        return char_out, pos_out

# %%
stim_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.npy"
label_train_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-train.tsv"
stims_train = np.load(stim_train_path, allow_pickle=True)
lbls_train = pd.read_csv(label_train_path, sep="\t", index_col=0)

stim_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.npy"
label_val_path = "/G/MIMOlab/Codes/aim3_RNN/stimuli/stimulus_reg-validation.tsv"
stims_val = np.load(stim_val_path, allow_pickle=True)
lbls_val = pd.read_csv(label_val_path, sep="\t", index_col=0)


train_ds = MC_RNN_Dataset(stims_train, lbls_train)
val_ds = MC_RNN_Dataset(stims_val, lbls_val)
mdl_rnn = RNNConvShareSplit(num_classes=10, num_pos=2, kernel_size=5)
results_rnn = network_train(mdl_rnn, train_ds, val_ds, num_epochs=50, loss_weights=[1.0, 0.001])
# Out:
# Epoch 1/50 - Train (char, pos): (10.13%, 1466.85 pix^2)  Validation (char, pos): (10.29%, 610.03 pix^2)
# Epoch 2/50 - Train (char, pos): (10.20%, 464.04 pix^2)  Validation (char, pos): (11.91%, 438.14 pix^2)
# Epoch 3/50 - Train (char, pos): (10.14%, 380.08 pix^2)  Validation (char, pos): (9.88%, 327.60 pix^2)
# Epoch 4/50 - Train (char, pos): (10.27%, 276.87 pix^2)  Validation (char, pos): (9.66%, 240.29 pix^2)
# Epoch 5/50 - Train (char, pos): (10.85%, 220.14 pix^2)  Validation (char, pos): (10.60%, 201.26 pix^2)
# Epoch 6/50 - Train (char, pos): (10.73%, 196.96 pix^2)  Validation (char, pos): (11.34%, 179.14 pix^2)
# Epoch 7/50 - Train (char, pos): (11.32%, 182.92 pix^2)  Validation (char, pos): (11.23%, 171.28 pix^2)
# Epoch 8/50 - Train (char, pos): (15.11%, 189.85 pix^2)  Validation (char, pos): (16.30%, 188.08 pix^2)
# Epoch 9/50 - Train (char, pos): (18.86%, 197.10 pix^2)  Validation (char, pos): (15.61%, 203.26 pix^2)
# Epoch 10/50 - Train (char, pos): (21.10%, 191.42 pix^2)  Validation (char, pos): (23.14%, 181.02 pix^2)
# Epoch 11/50 - Train (char, pos): (22.18%, 186.17 pix^2)  Validation (char, pos): (22.51%, 186.40 pix^2)
# Epoch 12/50 - Train (char, pos): (23.56%, 183.46 pix^2)  Validation (char, pos): (22.19%, 175.68 pix^2)
# Epoch 13/50 - Train (char, pos): (24.84%, 181.26 pix^2)  Validation (char, pos): (24.06%, 178.41 pix^2)
# Epoch 14/50 - Train (char, pos): (25.76%, 180.63 pix^2)  Validation (char, pos): (23.87%, 179.91 pix^2)
# Epoch 15/50 - Train (char, pos): (27.30%, 178.47 pix^2)  Validation (char, pos): (23.46%, 176.70 pix^2)
# Epoch 16/50 - Train (char, pos): (29.26%, 175.25 pix^2)  Validation (char, pos): (26.15%, 175.54 pix^2)
# Epoch 17/50 - Train (char, pos): (30.90%, 175.76 pix^2)  Validation (char, pos): (26.94%, 175.55 pix^2)
# Epoch 18/50 - Train (char, pos): (32.99%, 174.25 pix^2)  Validation (char, pos): (29.60%, 178.02 pix^2)
# Epoch 19/50 - Train (char, pos): (34.70%, 176.32 pix^2)  Validation (char, pos): (32.40%, 190.94 pix^2)
# Epoch 20/50 - Train (char, pos): (37.17%, 175.76 pix^2)  Validation (char, pos): (32.58%, 179.53 pix^2)
# Epoch 21/50 - Train (char, pos): (38.34%, 175.89 pix^2)  Validation (char, pos): (33.71%, 180.59 pix^2)
# Epoch 22/50 - Train (char, pos): (39.51%, 176.40 pix^2)  Validation (char, pos): (32.82%, 186.77 pix^2)
# Epoch 23/50 - Train (char, pos): (41.29%, 175.85 pix^2)  Validation (char, pos): (33.97%, 179.62 pix^2)
# Epoch 24/50 - Train (char, pos): (42.74%, 175.82 pix^2)  Validation (char, pos): (34.92%, 188.98 pix^2)
# Epoch 25/50 - Train (char, pos): (45.53%, 173.21 pix^2)  Validation (char, pos): (36.49%, 177.48 pix^2)
# Epoch 26/50 - Train (char, pos): (46.43%, 170.81 pix^2)  Validation (char, pos): (37.79%, 179.41 pix^2)
# Epoch 27/50 - Train (char, pos): (46.19%, 175.06 pix^2)  Validation (char, pos): (37.06%, 183.22 pix^2)
# Epoch 28/50 - Train (char, pos): (49.77%, 170.97 pix^2)  Validation (char, pos): (37.90%, 180.99 pix^2)
# Epoch 29/50 - Train (char, pos): (50.17%, 171.78 pix^2)  Validation (char, pos): (37.57%, 177.40 pix^2)
# Epoch 30/50 - Train (char, pos): (52.13%, 170.71 pix^2)  Validation (char, pos): (40.67%, 181.77 pix^2)
# Epoch 31/50 - Train (char, pos): (53.65%, 170.01 pix^2)  Validation (char, pos): (39.12%, 183.01 pix^2)
# Epoch 32/50 - Train (char, pos): (54.84%, 169.77 pix^2)  Validation (char, pos): (40.55%, 187.83 pix^2)
# Epoch 33/50 - Train (char, pos): (55.40%, 171.44 pix^2)  Validation (char, pos): (39.50%, 185.91 pix^2)
# Epoch 34/50 - Train (char, pos): (56.19%, 170.95 pix^2)  Validation (char, pos): (39.73%, 191.08 pix^2)
# Epoch 35/50 - Train (char, pos): (56.64%, 171.52 pix^2)  Validation (char, pos): (41.31%, 184.37 pix^2)
# Epoch 36/50 - Train (char, pos): (58.86%, 168.89 pix^2)  Validation (char, pos): (40.03%, 182.59 pix^2)
# Epoch 37/50 - Train (char, pos): (60.97%, 167.93 pix^2)  Validation (char, pos): (40.39%, 188.02 pix^2)
# Epoch 38/50 - Train (char, pos): (58.57%, 172.30 pix^2)  Validation (char, pos): (41.21%, 184.47 pix^2)
# Epoch 39/50 - Train (char, pos): (62.69%, 166.49 pix^2)  Validation (char, pos): (39.80%, 185.09 pix^2)
# Epoch 40/50 - Train (char, pos): (63.85%, 166.57 pix^2)  Validation (char, pos): (36.77%, 192.13 pix^2)
# Epoch 41/50 - Train (char, pos): (64.51%, 168.79 pix^2)  Validation (char, pos): (42.58%, 184.19 pix^2)
# Epoch 42/50 - Train (char, pos): (67.22%, 164.94 pix^2)  Validation (char, pos): (41.28%, 184.10 pix^2)
# Epoch 43/50 - Train (char, pos): (66.35%, 165.11 pix^2)  Validation (char, pos): (42.44%, 193.04 pix^2)
# Epoch 44/50 - Train (char, pos): (66.88%, 166.93 pix^2)  Validation (char, pos): (41.56%, 193.06 pix^2)
# Epoch 45/50 - Train (char, pos): (64.56%, 171.08 pix^2)  Validation (char, pos): (43.27%, 188.85 pix^2)
# Epoch 46/50 - Train (char, pos): (68.97%, 165.49 pix^2)  Validation (char, pos): (42.02%, 194.55 pix^2)
# Epoch 47/50 - Train (char, pos): (67.78%, 167.11 pix^2)  Validation (char, pos): (44.38%, 188.57 pix^2)
# Epoch 48/50 - Train (char, pos): (70.80%, 163.74 pix^2)  Validation (char, pos): (39.88%, 201.96 pix^2)
# Epoch 49/50 - Train (char, pos): (70.56%, 164.90 pix^2)  Validation (char, pos): (43.69%, 187.58 pix^2)
# Epoch 50/50 - Train (char, pos): (72.47%, 163.02 pix^2)  Validation (char, pos): (44.08%, 189.20 pix^2)
